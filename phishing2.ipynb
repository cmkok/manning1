# %%
# Load the CSV
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
url='https://raw.githubusercontent.com/sayakpaul/Manning-Phishing-Websites-Detection/master/Phishing.csv'
df=pd.read_csv(url)

# %%
# Extract and count the value in Result column
result = df.loc[:,'Result']
# print(result)
# print(Counter(result))
# d = Counter(result)
# print (d)

# import the data as df
df1 = pd.DataFrame.from_dict(d, orient='index').reset_index()
df1 = df1.rename(columns={'index':'Class', 0:'Num_Observations'})
print(df1)

ax = df1[['Class','Num_Observations']].plot(x='Class', y='Num_Observations', kind='bar', width=1.0, align='center', title ="Phishing Websites", figsize=(5, 10), legend=True, fontsize=12)
ax.set_xlabel("Class", fontsize=12)
ax.set_ylabel("Number Observations", fontsize=12)
plt.show()
# Out:
# Counter({1: 6157, -1: 4898})
#    Class  Num_Observations
# 0     -1              4898
# 1      1              6157

# %%
# print (df[('having_IP_Address')].head(20))
print ( df[ df["having_IP_Address"] == -1 ].shape[0] )
print ( df['having_IP_Address'].std()  )
# Out:
# 3793
# 0.9495338154105023
